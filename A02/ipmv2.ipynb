# %%
import numpy as np
from scipy.optimize import minimize
from scipy import linalg
import matplotlib.pyplot as plt
import math
from scipy import optimize
import random
from matplotlib.patches import Circle

# Part 2: Generate Noisy Point Set (code 2)

N = 100
half_n = N // 2
r = 10
x0_gt, y0_gt = 2, 3  # Center
s = r / 16

t = np.random.uniform(0, 2 * np.pi, half_n)
n = s * np.random.randn(half_n)
x = x0_gt + (r + n) * np.cos(t)
y = y0_gt + (r + n) * np.sin(t)
X_circ = np.hstack((x.reshape(half_n, 1), y.reshape(half_n, 1)))

s = 1.0
m, b = -1, 2
x = np.linspace(-12, 12, half_n)
y = m * x + b + s * np.random.randn(half_n)
X_line = np.hstack((x.reshape(half_n, 1), y.reshape(half_n, 1)))

X = np.vstack((X_circ, X_line))

# Plot the initial point set
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
ax.scatter(X_line[:, 0], X_line[:, 1], label='Line')
ax.scatter(X_circ[:, 0], X_circ[:, 1], label='Circle')

circle_gt = plt.Circle((x0_gt, y0_gt), r, color='red', fill=False, label='Ground truth circle')
ax.add_patch(circle_gt)
ax.plot(x0_gt, y0_gt, '+', color='red')

x_min, x_max = ax.get_xlim()
x_ = np.array([x_min, x_max])
y_ = m * x_ + b
plt.plot(x_, y_, color='green', label='Ground truth line')

plt.legend()
plt.title('Initial Noisy Point Set')
plt.show()

# Part 3: Estimate the Line using RANSAC (code 3)

def calculate_distance(x1, y1, x2, y2):
    distance_mag = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
    a = (x2 - x1) / distance_mag
    b = (y2 - y1) / distance_mag
    d = a * x1 + b * y1
    return a, b, d

def calc_tls(x, indices):
    a = x[0]
    b = x[1]
    d = x[2]
    return np.sum(np.square(a * data[indices, 0] + b * data[indices, 1] - d))

def g(x):
    return x[0] ** 2 + x[1] ** 2 - 1

constraints = ({'type': 'eq', 'fun': g})

def best_fit_line(X, x, t):
    a = x[0]
    b = x[1]
    d = x[2]
    e = np.absolute(a * X[:, 0] + b * X[:, 1] - d)
    return e < t

threshold_value = 1.0
d = 0.5 * N
s = 2

line_inliers = []
circle_inliers = []

max_iters = 100
iters = 0
best_line_model = []
best_error = np.inf
best_sample_line = []
best_inlier_line = []

while iters < max_iters:
    indices = np.random.randint(0, N, 2)
    x0 = np.array([1, 1, 0])
    res = minimize(fun=calc_tls, args=indices, x0=x0, tol=1e-6, constraints=constraints, options={'disp': True})
    line_inliers = best_fit_line(data, res.x, threshold_value)

    if line_inliers.sum() > d:
        x0 = res.x
        res = minimize(fun=calc_tls, args=line_inliers, x0=x0, tol=1e-6, constraints=constraints, options={'disp': True})
        if res.fun < best_error:
            best_error = res.fun
            best_line_model = res.x
            best_sample_line = data[indices, :]
            best_inlier_line = line_inliers
            res_only_with_sample = x0
            print("Best line model: ", best_line_model)
            print("Best error: ", best_error)
            print("Best sample: ", best_sample_line)
            print("Best inlier: ", best_inlier_line)
            print("Number of inliers: ", best_inlier_line.sum())
            print("Number of outliers: ", N - best_inlier_line.sum())
            print("Number of iterations: ", iters)
            print("------------------------------------------------------")

    iters += 1

print("The Best Line model got : ", best_line_model)

# Part 4: Fit Circle to Remnant (code 4)

def calculate_circle_parameters(points):
    x1, y1 = points[0]
    x2, y2 = points[1]
    x3, y3 = points[2]
    D = 2 * (x1 * (y2 - y3) + x2 * (y3 - y1) + x3 * (y1 - y2))
    Ux = ((x1**2 + y1**2) * (y2 - y3) + (x2**2 + y2**2) * (y3 - y1) + (x3**2 + y3**2) * (y1 - y2)) / D
    Uy = ((x1**2 + y1**2) * (x3 - x2) + (x2**2 + y2**2) * (x1 - x3) + (x3**2 + y3**2) * (x2 - x1)) / D
    r = np.sqrt((x1 - Ux)**2 + (y1 - Uy)**2)
    return Ux, Uy, r

def fit_circle_ransac(points, num_iterations, error_threshold, min_consensus):
    best_circle = None
    best_inliers = []

    for _ in range(num_iterations):
        sample_indices = np.random.choice(len(points), 3, replace=False)
        sample_points = points[sample_indices]
        x, y, r = calculate_circle_parameters(sample_points)
        radial_errors = np.abs(np.sqrt((points[:, 0] - x)**2 + (points[:, 1] - y)**2) - r)
        inliers = np.where(radial_errors < error_threshold)[0]
        if len(inliers) >= min_consensus and len(inliers) > len(best_inliers):
            best_inliers = inliers
            best_circle = (x, y, r)

    return best_circle, best_inliers

num_iterations_circle = 1000
error_threshold_circle = 0.85
min_consensus_circle = 40

best_circle, circle_inliers = fit_circle_ransac(X_circ, num_iterations_circle, error_threshold_circle, min_consensus_circle)

# Part 5: Visualize Line Outliers (code 5)

outliers_indices = np.where(np.logical_not(best_inlier_line))[0]
outliers_data = data[outliers_indices, :]

plt.subplots(figsize=(8, 8))
plt.scatter(outliers_data[:, 0], outliers_data[:, 1])
plt.title('Outliers from Line Estimation')
plt.show()

outliers_indices = np.where(np.logical_not(best_inlier_line))[0]
outliers_data = data[outliers_indices, :]

plt.subplots(figsize=(8, 8))
plt.scatter(outliers_data[:, 0], outliers_data[:, 1])
plt.title('Outliers from Line Estimation')
plt.show()

# Part 6: Visualize Line and Circle Fitting (code 6)

fig, ax = plt.subplots(1, 1, figsize=(8, 8))

# Scatter plot for the noisy point set
ax.scatter(X[:, 0], X[:, 1], label='Noisy Points')
ax.scatter(X_circ[:, 0], X_circ[:, 1], label='Circle')

if best_circle is not None:  # Check if the circle was successfully estimated
    x_circle, y_circle, r_circle = best_circle
    circle = Circle((x_circle, y_circle), r_circle, color='magenta', fill=False, label='Best Fit Circle')
    ax.add_patch(circle)
    ax.scatter(X_circ[circle_inliers, 0], X_circ[circle_inliers, 1], color='blue', label='Circle Inliers')
circle_gt = Circle((x0_gt, y0_gt), r, color='red', fill=False, label='Ground Truth Circle')
ax.add_patch(circle_gt)
ax.plot(x0_gt, y0_gt, '+', color='orange')
ax.legend()
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Line and Circle Fitting using RANSAC')

plt.show()

# Part 7: Visualize Line, Circle, and Inliers (code 7)

fig, ax = plt.subplots(figsize=(8, 8))
ax.scatter(X[:, 0], X[:, 1], label='Noisy Points')
ax.scatter(X_circ[:, 0], X_circ[:, 1], label='Circle')

x_circle, y_circle, r_circle = best_circle
circle = Circle((x_circle, y_circle), r_circle, color='green', fill=False, label='Best Fit Circle')
ax.add_patch(circle)
ax.scatter(X_circ[circle_inliers, 0], X_circ[circle_inliers, 1], color='cyan', label='Circle Inliers')
circle_gt = Circle((x0_gt, y0_gt), r, color='purple', fill=False, label='Ground Truth Circle')
ax.add_patch(circle_gt)
ax.plot(x0_gt, y0_gt, '+', color='brown')

x_min, x_max = ax.get_xlim()
x_ = np.array([x_min, x_max])
y_ = (-best_line_model[1] * x_ + best_line_model[2]) / best_line_model[1]
plt.plot(x_, y_, label='RANSAC line')
x_ = np.array([x_min, x_max])
y_ = m * x_ + b
plt.plot(x_, y_, color='orange', label='Ground Truth Line')
plt.legend()
plt.show()
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3825218975356852e-08
#             Iterations: 9
#             Function evaluations: 44
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.939134786300225
#             Iterations: 4
#             Function evaluations: 22
#             Gradient evaluations: 4
# Best line model:  [-0.71478524  0.69934405  1.33841326]
# Best error:  7.939134786300225
# Best sample:  [[-10.04081633  -8.85161738]
#  [ -1.71428571  -0.09421633]]
# Best inlier:  [ True False False False False False False False False  True  True False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False  True  True  True  True  True  True  True  True False  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True False  True  True
#   True  True  True  True]
# Number of inliers:  51
# Number of outliers:  49
# Number of iterations:  0
# ------------------------------------------------------
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6141130872376895e-08
#             Iterations: 12
#             Function evaluations: 56
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.4400654525908126e-10
#             Iterations: 13
#             Function evaluations: 58
#             Gradient evaluations: 13
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2086997494692334e-07
#             Iterations: 10
#             Function evaluations: 46
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.0405050065984706e-11
#             Iterations: 9
#             Function evaluations: 47
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.692468781894897
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9177455671781626e-12
#             Iterations: 16
#             Function evaluations: 77
#             Gradient evaluations: 16
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.040822477152044e-11
#             Iterations: 13
#             Function evaluations: 60
#             Gradient evaluations: 13
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.751482329840239e-11
#             Iterations: 9
#             Function evaluations: 43
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.284251625470542e-12
#             Iterations: 9
#             Function evaluations: 41
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3263927423568746e-07
#             Iterations: 8
#             Function evaluations: 39
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6098340950610934e-08
#             Iterations: 12
#             Function evaluations: 61
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.7282606372425554e-09
#             Iterations: 10
#             Function evaluations: 51
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3780156026606609e-14
#             Iterations: 11
#             Function evaluations: 54
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.904221752900832e-09
#             Iterations: 10
#             Function evaluations: 49
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1385762521792027e-09
#             Iterations: 16
#             Function evaluations: 72
#             Gradient evaluations: 16
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6627072868628212e-09
#             Iterations: 13
#             Function evaluations: 58
#             Gradient evaluations: 13
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.477878191590985
#             Iterations: 4
#             Function evaluations: 22
#             Gradient evaluations: 4
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6174870565353466e-07
#             Iterations: 8
#             Function evaluations: 38
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.816772671084358e-10
#             Iterations: 9
#             Function evaluations: 40
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9417135666935235e-09
#             Iterations: 10
#             Function evaluations: 52
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.024799623433602e-11
#             Iterations: 7
#             Function evaluations: 33
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.354478722745387e-08
#             Iterations: 10
#             Function evaluations: 52
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.281794116738191e-12
#             Iterations: 15
#             Function evaluations: 71
#             Gradient evaluations: 15
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.488346256797762e-09
#             Iterations: 10
#             Function evaluations: 46
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.338267464757739e-10
#             Iterations: 16
#             Function evaluations: 73
#             Gradient evaluations: 16
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0027265783591232e-09
#             Iterations: 12
#             Function evaluations: 58
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.79985074404006e-09
#             Iterations: 7
#             Function evaluations: 30
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.585208107262673e-10
#             Iterations: 9
#             Function evaluations: 43
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0987304094389403e-07
#             Iterations: 9
#             Function evaluations: 45
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4596348673125932e-13
#             Iterations: 8
#             Function evaluations: 42
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.691446023442162e-09
#             Iterations: 6
#             Function evaluations: 27
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3845270695990872e-11
#             Iterations: 18
#             Function evaluations: 83
#             Gradient evaluations: 18
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.343225603883789e-12
#             Iterations: 9
#             Function evaluations: 42
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.564657513892967e-10
#             Iterations: 9
#             Function evaluations: 40
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.856840217023632e-09
#             Iterations: 17
#             Function evaluations: 76
#             Gradient evaluations: 17
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6979715504282034e-08
#             Iterations: 9
#             Function evaluations: 39
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.193784044971165e-11
#             Iterations: 14
#             Function evaluations: 65
#             Gradient evaluations: 14
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.266617627752017e-08
#             Iterations: 10
#             Function evaluations: 50
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.495809109939514e-10
#             Iterations: 10
#             Function evaluations: 48
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.939134482617441
#             Iterations: 4
#             Function evaluations: 23
#             Gradient evaluations: 4
# Best line model:  [-0.71478496  0.6993443   1.33841373]
# Best error:  7.939134482617441
# Best sample:  [[-4.65306122 -3.09429447]
#  [ 0.24489796  2.14448446]]
# Best inlier:  [ True False False False False False False False False  True  True False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False  True  True  True  True  True  True  True  True False  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True False  True  True
#   True  True  True  True]
# Number of inliers:  51
# Number of outliers:  49
# Number of iterations:  37
# ------------------------------------------------------
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.901283477741504e-10
#             Iterations: 18
#             Function evaluations: 87
#             Gradient evaluations: 18
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.290844227991102e-08
#             Iterations: 8
#             Function evaluations: 37
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.094609833224111e-07
#             Iterations: 11
#             Function evaluations: 50
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.345414474552287e-13
#             Iterations: 12
#             Function evaluations: 59
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.25082900192158e-10
#             Iterations: 8
#             Function evaluations: 43
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8196593909795574e-08
#             Iterations: 10
#             Function evaluations: 47
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.175958283650838e-10
#             Iterations: 9
#             Function evaluations: 43
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.933326320884107e-09
#             Iterations: 9
#             Function evaluations: 41
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.468049686347895e-12
#             Iterations: 8
#             Function evaluations: 36
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.81426763685901e-13
#             Iterations: 11
#             Function evaluations: 51
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.351915201149965e-12
#             Iterations: 12
#             Function evaluations: 55
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2630688470659517e-10
#             Iterations: 10
#             Function evaluations: 50
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.353753737044185
#             Iterations: 4
#             Function evaluations: 22
#             Gradient evaluations: 4
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.226606648824435e-10
#             Iterations: 10
#             Function evaluations: 46
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.193405249791368e-08
#             Iterations: 11
#             Function evaluations: 50
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.216861705369924e-10
#             Iterations: 8
#             Function evaluations: 39
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3309118980952164e-12
#             Iterations: 14
#             Function evaluations: 63
#             Gradient evaluations: 14
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.462000256670318e-10
#             Iterations: 8
#             Function evaluations: 39
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8434463638171705e-12
#             Iterations: 9
#             Function evaluations: 47
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5265550202457348e-13
#             Iterations: 12
#             Function evaluations: 57
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.129246362811046e-09
#             Iterations: 13
#             Function evaluations: 58
#             Gradient evaluations: 13
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.65818768831638e-09
#             Iterations: 7
#             Function evaluations: 32
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.779713810648074e-08
#             Iterations: 8
#             Function evaluations: 37
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.386818769080152e-09
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.769585173464761e-11
#             Iterations: 11
#             Function evaluations: 55
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.106666189327633e-10
#             Iterations: 9
#             Function evaluations: 43
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.01363214309536e-10
#             Iterations: 12
#             Function evaluations: 54
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8595118872256012e-07
#             Iterations: 9
#             Function evaluations: 45
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9417135666935235e-09
#             Iterations: 10
#             Function evaluations: 52
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1294645595081509e-10
#             Iterations: 13
#             Function evaluations: 63
#             Gradient evaluations: 13
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8731884231909243e-09
#             Iterations: 11
#             Function evaluations: 49
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.39388968523201e-09
#             Iterations: 10
#             Function evaluations: 45
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.314706438316453e-09
#             Iterations: 11
#             Function evaluations: 57
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.376761616462242e-07
#             Iterations: 12
#             Function evaluations: 57
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.1327132890807225e-12
#             Iterations: 7
#             Function evaluations: 33
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.358483083247897e-13
#             Iterations: 12
#             Function evaluations: 57
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0089052743537525e-12
#             Iterations: 10
#             Function evaluations: 45
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5342775776498574e-07
#             Iterations: 10
#             Function evaluations: 45
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.821693694225759e-11
#             Iterations: 10
#             Function evaluations: 47
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.913718872390853e-09
#             Iterations: 10
#             Function evaluations: 46
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7094124902327704e-10
#             Iterations: 9
#             Function evaluations: 42
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.972567913884943e-11
#             Iterations: 21
#             Function evaluations: 103
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7823085845188227e-09
#             Iterations: 12
#             Function evaluations: 56
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3958176642217284e-12
#             Iterations: 8
#             Function evaluations: 41
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.692468812099854
#             Iterations: 4
#             Function evaluations: 22
#             Gradient evaluations: 4
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.087561472767031e-13
#             Iterations: 14
#             Function evaluations: 63
#             Gradient evaluations: 14
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9881422985143757e-10
#             Iterations: 11
#             Function evaluations: 48
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1448002535771885e-11
#             Iterations: 15
#             Function evaluations: 70
#             Gradient evaluations: 15
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.987932567704606e-09
#             Iterations: 8
#             Function evaluations: 38
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.34011362780847e-10
#             Iterations: 7
#             Function evaluations: 34
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7210095156278015e-07
#             Iterations: 9
#             Function evaluations: 44
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.0965249950729383e-07
#             Iterations: 11
#             Function evaluations: 54
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.414603059919228e-14
#             Iterations: 9
#             Function evaluations: 45
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0720666222011577e-07
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8090943336572646e-08
#             Iterations: 12
#             Function evaluations: 60
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.692468781908497
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.2450160978255554e-08
#             Iterations: 8
#             Function evaluations: 39
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.322233563713265e-08
#             Iterations: 7
#             Function evaluations: 30
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.9113118405104736e-09
#             Iterations: 8
#             Function evaluations: 40
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5275120245171125e-13
#             Iterations: 13
#             Function evaluations: 58
#             Gradient evaluations: 13
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5963194155690818e-07
#             Iterations: 15
#             Function evaluations: 71
#             Gradient evaluations: 15
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2180341069007933e-08
#             Iterations: 11
#             Function evaluations: 54
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.538959699762624e-10
#             Iterations: 20
#             Function evaluations: 96
#             Gradient evaluations: 20
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8039980476202457e-08
#             Iterations: 9
#             Function evaluations: 40
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.076260735879748e-11
#             Iterations: 13
#             Function evaluations: 59
#             Gradient evaluations: 13
# The Best Line model got :  [-0.71478496  0.6993443   1.33841373]
